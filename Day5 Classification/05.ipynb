# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import joblib
#       3 # 'best_model' ko use karte hue save karein
# ----> 4 joblib.dump(best_model, 'churn_model.pkl')
#       5 print("Model successfully saved as churn_model.pkl! 🎉")
#
# NameError: name 'best_model' is not defined
