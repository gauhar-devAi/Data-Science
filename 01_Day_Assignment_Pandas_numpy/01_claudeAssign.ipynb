# %%
print("I am a Data Scientist")
# Out:
# I am a Data Scientist

# %%
name = "Gauhar Ali Khan"
age = 22
city = "Jauharabad"
goal = "Data Scientist"
hours_per_day = 5

# %%
print(f"My name is {name}.\n I am {age} years old.\n I live in {city}.\n My goal is to become {goal}\n My work is {hours_per_day} hours per day")
# Out:
# My name is Gauhar Ali Khan.
#  I am 22 years old.
#  I live in Jauharabad.
#  My goal is to become Data Scientist
#  My work is 5 hours per day
